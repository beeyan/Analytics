# %%
# !wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
# !apt update -q
# !apt install cuda gcc-6 g++-6 -y -q
# !ln -s /usr/bin/gcc-6 /usr/local/cuda/bin/gcc
# !ln -s /usr/bin/g++-6 /usr/local/cuda/bin/g++

# !curl -sSL "https://julialang-s3.julialang.org/bin/linux/x64/1.0/julia-1.0.0-linux-x86_64.tar.gz" -o julia.tar.gz
# !tar -xzf julia.tar.gz -C /usr --strip-components 1
# !rm -rf julia.tar.gz*
# !julia -e 'using Pkg; pkg"add IJulia; add CuArrays; add Flux; precompile"'
# Out:
# --2020-07-11 02:51:30--  https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.195.57.194
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.195.57.194|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.0/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64.deb?T87i9duCJifX1cTb4qXkXxWzxnp5lE8R5m2naNfRK_FKFO1YPI40VB_Q0175KNYm2MTbjrdiku0FAXf9Q-0NTYMM8qy-P2-BQKi-j4gUivZzbO486rycZl-JjclifrdkizIk0dmK5FFnYyk3YLB1vEknbD7kv_21s5Q2ZOI3Msx5O71IKbei-W6O9JAWKLBW0c3DNJedW7SxQ-CGVfgq [following]
# --2020-07-11 02:51:31--  https://developer.download.nvidia.com/compute/cuda/9.0/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64.deb?T87i9duCJifX1cTb4qXkXxWzxnp5lE8R5m2naNfRK_FKFO1YPI40VB_Q0175KNYm2MTbjrdiku0FAXf9Q-0NTYMM8qy-P2-BQKi-j4gUivZzbO486rycZl-JjclifrdkizIk0dmK5FFnYyk3YLB1vEknbD7kv_21s5Q2ZOI3Msx5O71IKbei-W6O9JAWKLBW0c3DNJedW7SxQ-CGVfgq
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1212738714 (1.1G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.13G   194MB/s    in 6.1s
#
# 2020-07-11 02:51:37 (189 MB/s) - ‘cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb’ saved [1212738714/1212738714]
#
# Selecting previously unselected package cuda-repo-ubuntu1604-9-0-local.
# (Reading database ... 144379 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb ...
# Unpacking cuda-repo-ubuntu1604-9-0-local (9.0.176-1) ...
# Setting up cuda-repo-ubuntu1604-9-0-local (9.0.176-1) ...
# OK
# Get:1 file:/var/cuda-repo-9-0-local  InRelease
# Ign:1 file:/var/cuda-repo-9-0-local  InRelease
# Get:2 file:/var/cuda-repo-9-0-local  Release [574 B]
# Get:2 file:/var/cuda-repo-9-0-local  Release [574 B]
# Get:3 file:/var/cuda-repo-9-0-local  Release.gpg [819 B]
# Get:3 file:/var/cuda-repo-9-0-local  Release.gpg [819 B]
# Get:4 file:/var/cuda-repo-9-0-local  Packages [15.4 kB]
# Ign:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [94.1 kB]
# Get:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Hit:15 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:16 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:19 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [41.2 kB]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [214 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [869 kB]
# Get:21 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,846 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [13.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [103 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,405 kB]
# Get:26 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,003 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,303 kB]
# Get:28 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [9,282 B]
# Get:29 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [89.0 kB]
# Get:30 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [891 kB]
# Fetched 8,155 kB in 5s (1,493 kB/s)
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 81 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cpp-6 cuda-11-0 cuda-command-line-tools-11-0 cuda-compiler-11-0
#   cuda-cudart-11-0 cuda-cudart-dev-11-0 cuda-cuobjdump-11-0 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-demo-suite-11-0 cuda-documentation-11-0
#   cuda-driver-dev-11-0 cuda-drivers cuda-drivers-450 cuda-gdb-11-0
#   cuda-libraries-11-0 cuda-libraries-dev-11-0 cuda-memcheck-11-0
#   cuda-nsight-11-0 cuda-nsight-compute-11-0 cuda-nsight-systems-11-0
#   cuda-nvcc-11-0 cuda-nvdisasm-11-0 cuda-nvml-dev-11-0 cuda-nvprof-11-0
#   cuda-nvprune-11-0 cuda-nvrtc-11-0 cuda-nvrtc-dev-11-0 cuda-nvtx-11-0
#   cuda-nvvp-11-0 cuda-runtime-11-0 cuda-samples-11-0 cuda-sanitizer-11-0
#   cuda-toolkit-11-0 cuda-tools-11-0 cuda-visual-tools-11-0 gcc-6-base libasan3
#   libcublas-11-0 libcublas-dev-11-0 libcufft-11-0 libcufft-dev-11-0
#   libcurand-11-0 libcurand-dev-11-0 libcusolver-11-0 libcusolver-dev-11-0
#   libcusparse-11-0 libcusparse-dev-11-0 libgcc-6-dev libnpp-11-0
#   libnpp-dev-11-0 libnvidia-cfg1-450 libnvidia-common-450
#   libnvidia-compute-450 libnvidia-decode-450 libnvidia-encode-450
#   libnvidia-extra-450 libnvidia-fbc1-450 libnvidia-gl-450 libnvidia-ifr1-450
#   libnvjpeg-11-0 libnvjpeg-dev-11-0 libstdc++-6-dev nvidia-compute-utils-450
#   nvidia-dkms-450 nvidia-driver-450 nvidia-kernel-common-450
#   nvidia-kernel-source-450 nvidia-modprobe nvidia-settings nvidia-utils-450
#   xserver-xorg-video-nvidia-450
# Suggested packages:
#   gcc-6-locales g++-6-multilib gcc-6-doc libstdc++6-6-dbg gcc-6-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan3-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx2-dbg
#   libquadmath0-dbg libstdc++-6-doc
# Recommended packages:
#   nvidia-prime libnvidia-compute-450:i386 libnvidia-decode-450:i386
#   libnvidia-encode-450:i386 libnvidia-ifr1-450:i386 libnvidia-fbc1-450:i386
#   libnvidia-gl-450:i386
# The following NEW packages will be installed:
#   cpp-6 cuda cuda-11-0 cuda-command-line-tools-11-0 cuda-compiler-11-0
#   cuda-cudart-11-0 cuda-cudart-dev-11-0 cuda-cuobjdump-11-0 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-demo-suite-11-0 cuda-documentation-11-0
#   cuda-driver-dev-11-0 cuda-gdb-11-0 cuda-libraries-11-0
#   cuda-libraries-dev-11-0 cuda-memcheck-11-0 cuda-nsight-11-0
#   cuda-nsight-compute-11-0 cuda-nsight-systems-11-0 cuda-nvcc-11-0
#   cuda-nvdisasm-11-0 cuda-nvml-dev-11-0 cuda-nvprof-11-0 cuda-nvprune-11-0
#   cuda-nvrtc-11-0 cuda-nvrtc-dev-11-0 cuda-nvtx-11-0 cuda-nvvp-11-0
#   cuda-runtime-11-0 cuda-samples-11-0 cuda-sanitizer-11-0 cuda-toolkit-11-0
#   cuda-tools-11-0 cuda-visual-tools-11-0 g++-6 gcc-6 gcc-6-base libasan3
#   libcublas-11-0 libcublas-dev-11-0 libcufft-11-0 libcufft-dev-11-0
#   libcurand-11-0 libcurand-dev-11-0 libcusolver-11-0 libcusolver-dev-11-0
#   libcusparse-11-0 libcusparse-dev-11-0 libgcc-6-dev libnpp-11-0
#   libnpp-dev-11-0 libnvidia-extra-450 libnvjpeg-11-0 libnvjpeg-dev-11-0
#   libstdc++-6-dev
# The following packages will be upgraded:
#   cuda-drivers cuda-drivers-450 libnvidia-cfg1-450 libnvidia-common-450
#   libnvidia-compute-450 libnvidia-decode-450 libnvidia-encode-450
#   libnvidia-fbc1-450 libnvidia-gl-450 libnvidia-ifr1-450
#   nvidia-compute-utils-450 nvidia-dkms-450 nvidia-driver-450
#   nvidia-kernel-common-450 nvidia-kernel-source-450 nvidia-modprobe
#   nvidia-settings nvidia-utils-450 xserver-xorg-video-nvidia-450
# 19 upgraded, 56 newly installed, 0 to remove and 62 not upgraded.
# Need to get 1,709 MB of archives.
# After this operation, 4,123 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-cudart-11-0 11.0.194-1 [129 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvrtc-11-0 11.0.194-1 [6,521 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas-11-0 11.1.0.229-1 [118 MB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 gcc-6-base amd64 6.5.0-2ubuntu1~18.04 [16.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 cpp-6 amd64 6.5.0-2ubuntu1~18.04 [6,396 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcufft-11-0 10.2.0.218-1 [94.1 MB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libasan3 amd64 6.5.0-2ubuntu1~18.04 [313 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libgcc-6-dev amd64 6.5.0-2ubuntu1~18.04 [2,308 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 gcc-6 amd64 6.5.0-2ubuntu1~18.04 [7,067 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libstdc++-6-dev amd64 6.5.0-2ubuntu1~18.04 [1,437 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 g++-6 amd64 6.5.0-2ubuntu1~18.04 [7,213 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcurand-11-0 10.2.1.218-1 [39.2 MB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcusolver-11-0 10.5.0.218-1 [277 MB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcusparse-11-0 11.1.0.218-1 [71.2 MB]
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnpp-11-0 11.1.0.218-1 [56.6 MB]
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvjpeg-11-0 11.1.0.218-1 [1,391 kB]
# Get:17 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-libraries-11-0 11.0.2-1 [2,490 B]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-common-450 450.51.05-0ubuntu1 [10.0 kB]
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-driver-450 450.51.05-0ubuntu1 [419 kB]
# Get:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-gl-450 450.51.05-0ubuntu1 [60.4 MB]
# Get:21 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-dkms-450 450.51.05-0ubuntu1 [26.7 kB]
# Get:22 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-kernel-source-450 450.51.05-0ubuntu1 [11.8 MB]
# Get:23 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-kernel-common-450 450.51.05-0ubuntu1 [9,818 B]
# Get:24 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-decode-450 450.51.05-0ubuntu1 [1,103 kB]
# Get:25 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-compute-450 450.51.05-0ubuntu1 [21.8 MB]
# Get:26 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-extra-450 450.51.05-0ubuntu1 [39.5 kB]
# Get:27 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-compute-utils-450 450.51.05-0ubuntu1 [123 kB]
# Get:28 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-encode-450 450.51.05-0ubuntu1 [39.4 kB]
# Get:29 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-utils-450 450.51.05-0ubuntu1 [366 kB]
# Get:30 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  xserver-xorg-video-nvidia-450 450.51.05-0ubuntu1 [1,536 kB]
# Get:31 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-cfg1-450 450.51.05-0ubuntu1 [75.0 kB]
# Get:32 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-ifr1-450 450.51.05-0ubuntu1 [68.5 kB]
# Get:33 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-fbc1-450 450.51.05-0ubuntu1 [49.7 kB]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-modprobe 450.51.05-0ubuntu1 [19.7 kB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-settings 450.51.05-0ubuntu1 [920 kB]
# Get:36 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers 450.51.05-1 [2,504 B]
# Get:37 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers-450 450.51.05-1 [2,628 B]
# Get:38 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-runtime-11-0 11.0.2-1 [2,424 B]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-cuobjdump-11-0 11.0.194-1 [103 kB]
# Get:40 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-driver-dev-11-0 11.0.194-1 [25.0 kB]
# Get:41 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-cudart-dev-11-0 11.0.194-1 [1,662 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvcc-11-0 11.0.194-1 [21.1 MB]
# Get:43 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvprune-11-0 11.0.167-1 [53.1 kB]
# Get:44 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-compiler-11-0 11.0.2-1 [2,416 B]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvrtc-dev-11-0 11.0.194-1 [22.1 kB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas-dev-11-0 11.1.0.229-1 [120 MB]
# Get:47 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcufft-dev-11-0 10.2.0.218-1 [172 MB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcurand-dev-11-0 10.2.1.218-1 [39.2 MB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcusolver-dev-11-0 10.5.0.218-1 [17.6 MB]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcusparse-dev-11-0 11.1.0.218-1 [71.4 MB]
# Get:51 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnpp-dev-11-0 11.1.0.218-1 [57.4 MB]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvjpeg-dev-11-0 11.1.0.218-1 [1,321 kB]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-libraries-dev-11-0 11.0.2-1 [2,514 B]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-cupti-11-0 11.0.194-1 [10.5 MB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-cupti-dev-11-0 11.0.194-1 [2,276 kB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvdisasm-11-0 11.0.194-1 [27.3 MB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-gdb-11-0 11.0.194-1 [3,891 kB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-memcheck-11-0 11.0.194-1 [144 kB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvprof-11-0 11.0.194-1 [1,911 kB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvtx-11-0 11.0.167-1 [51.1 kB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-sanitizer-11-0 11.0.194-1 [7,220 kB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-command-line-tools-11-0 11.0.2-1 [2,474 B]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nsight-compute-11-0 11.0.2-1 [3,718 B]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nsight-systems-11-0 11.0.2-1 [3,280 B]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nsight-11-0 11.0.194-1 [119 MB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvml-dev-11-0 11.0.167-1 [71.9 kB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvvp-11-0 11.0.194-1 [115 MB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-visual-tools-11-0 11.0.2-1 [2,942 B]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-tools-11-0 11.0.2-1 [2,380 B]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-samples-11-0 11.0.194-1 [68.1 MB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-documentation-11-0 11.0.207-1 [59.6 MB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-toolkit-11-0 11.0.2-1 [2,728 B]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-demo-suite-11-0 11.0.167-1 [3,948 kB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-11-0 11.0.2-1 [2,450 B]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda 11.0.2-1 [2,392 B]
# Fetched 1,709 MB in 29s (58.9 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package gcc-6-base:amd64.
# (Reading database ... 144438 files and directories currently installed.)
# Preparing to unpack .../00-gcc-6-base_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking gcc-6-base:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package cpp-6.
# Preparing to unpack .../01-cpp-6_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking cpp-6 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package cuda-cudart-11-0.
# Preparing to unpack .../02-cuda-cudart-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-cudart-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvrtc-11-0.
# Preparing to unpack .../03-cuda-nvrtc-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvrtc-11-0 (11.0.194-1) ...
# Selecting previously unselected package libcublas-11-0.
# Preparing to unpack .../04-libcublas-11-0_11.1.0.229-1_amd64.deb ...
# Unpacking libcublas-11-0 (11.1.0.229-1) ...
# Selecting previously unselected package libcufft-11-0.
# Preparing to unpack .../05-libcufft-11-0_10.2.0.218-1_amd64.deb ...
# Unpacking libcufft-11-0 (10.2.0.218-1) ...
# Selecting previously unselected package libcurand-11-0.
# Preparing to unpack .../06-libcurand-11-0_10.2.1.218-1_amd64.deb ...
# Unpacking libcurand-11-0 (10.2.1.218-1) ...
# Selecting previously unselected package libcusolver-11-0.
# Preparing to unpack .../07-libcusolver-11-0_10.5.0.218-1_amd64.deb ...
# Unpacking libcusolver-11-0 (10.5.0.218-1) ...
# Selecting previously unselected package libcusparse-11-0.
# Preparing to unpack .../08-libcusparse-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libcusparse-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnpp-11-0.
# Preparing to unpack .../09-libnpp-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnpp-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnvjpeg-11-0.
# Preparing to unpack .../10-libnvjpeg-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnvjpeg-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package cuda-libraries-11-0.
# Preparing to unpack .../11-cuda-libraries-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-libraries-11-0 (11.0.2-1) ...
# Preparing to unpack .../12-libnvidia-common-450_450.51.05-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../13-nvidia-driver-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../14-libnvidia-gl-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-gl-450:amd64 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../15-nvidia-dkms-450_450.51.05-0ubuntu1_amd64.deb ...
# Removing all DKMS Modules
# Done.
# Unpacking nvidia-dkms-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../16-nvidia-kernel-source-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../17-nvidia-kernel-common-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../18-libnvidia-decode-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-450:amd64 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../19-libnvidia-compute-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-450:amd64 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-450:amd64.
# Preparing to unpack .../20-libnvidia-extra-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-450:amd64 (450.51.05-0ubuntu1) ...
# Preparing to unpack .../21-nvidia-compute-utils-450_450.51.05-0ubuntu1_amd64.deb ...
# System has not been booted with systemd as init system (PID 1). Can't operate.
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Unpacking nvidia-compute-utils-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../22-libnvidia-encode-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-450:amd64 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../23-nvidia-utils-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../24-xserver-xorg-video-nvidia-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-450 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../25-libnvidia-cfg1-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-450:amd64 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../26-libnvidia-ifr1-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-ifr1-450:amd64 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../27-libnvidia-fbc1-450_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-450:amd64 (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../28-nvidia-modprobe_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../29-nvidia-settings_450.51.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (450.51.05-0ubuntu1) over (450.36.06-0ubuntu1) ...
# Preparing to unpack .../30-cuda-drivers_450.51.05-1_amd64.deb ...
# Unpacking cuda-drivers (450.51.05-1) over (450.36.06-1) ...
# Preparing to unpack .../31-cuda-drivers-450_450.51.05-1_amd64.deb ...
# Unpacking cuda-drivers-450 (450.51.05-1) over (450.36.06-1) ...
# Selecting previously unselected package cuda-runtime-11-0.
# Preparing to unpack .../32-cuda-runtime-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-runtime-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-cuobjdump-11-0.
# Preparing to unpack .../33-cuda-cuobjdump-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-cuobjdump-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-driver-dev-11-0.
# Preparing to unpack .../34-cuda-driver-dev-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-driver-dev-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-cudart-dev-11-0.
# Preparing to unpack .../35-cuda-cudart-dev-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-cudart-dev-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvcc-11-0.
# Preparing to unpack .../36-cuda-nvcc-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvcc-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvprune-11-0.
# Preparing to unpack .../37-cuda-nvprune-11-0_11.0.167-1_amd64.deb ...
# Unpacking cuda-nvprune-11-0 (11.0.167-1) ...
# Selecting previously unselected package cuda-compiler-11-0.
# Preparing to unpack .../38-cuda-compiler-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-compiler-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-11-0.
# Preparing to unpack .../39-cuda-nvrtc-dev-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-11-0 (11.0.194-1) ...
# Selecting previously unselected package libcublas-dev-11-0.
# Preparing to unpack .../40-libcublas-dev-11-0_11.1.0.229-1_amd64.deb ...
# Unpacking libcublas-dev-11-0 (11.1.0.229-1) ...
# Selecting previously unselected package libcufft-dev-11-0.
# Preparing to unpack .../41-libcufft-dev-11-0_10.2.0.218-1_amd64.deb ...
# Unpacking libcufft-dev-11-0 (10.2.0.218-1) ...
# Selecting previously unselected package libcurand-dev-11-0.
# Preparing to unpack .../42-libcurand-dev-11-0_10.2.1.218-1_amd64.deb ...
# Unpacking libcurand-dev-11-0 (10.2.1.218-1) ...
# Selecting previously unselected package libcusolver-dev-11-0.
# Preparing to unpack .../43-libcusolver-dev-11-0_10.5.0.218-1_amd64.deb ...
# Unpacking libcusolver-dev-11-0 (10.5.0.218-1) ...
# Selecting previously unselected package libcusparse-dev-11-0.
# Preparing to unpack .../44-libcusparse-dev-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libcusparse-dev-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnpp-dev-11-0.
# Preparing to unpack .../45-libnpp-dev-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnpp-dev-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnvjpeg-dev-11-0.
# Preparing to unpack .../46-libnvjpeg-dev-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnvjpeg-dev-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package cuda-libraries-dev-11-0.
# Preparing to unpack .../47-cuda-libraries-dev-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-libraries-dev-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-cupti-11-0.
# Preparing to unpack .../48-cuda-cupti-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-cupti-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-cupti-dev-11-0.
# Preparing to unpack .../49-cuda-cupti-dev-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-cupti-dev-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvdisasm-11-0.
# Preparing to unpack .../50-cuda-nvdisasm-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvdisasm-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-gdb-11-0.
# Preparing to unpack .../51-cuda-gdb-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-gdb-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-memcheck-11-0.
# Preparing to unpack .../52-cuda-memcheck-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-memcheck-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvprof-11-0.
# Preparing to unpack .../53-cuda-nvprof-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvprof-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvtx-11-0.
# Preparing to unpack .../54-cuda-nvtx-11-0_11.0.167-1_amd64.deb ...
# Unpacking cuda-nvtx-11-0 (11.0.167-1) ...
# Selecting previously unselected package cuda-sanitizer-11-0.
# Preparing to unpack .../55-cuda-sanitizer-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-sanitizer-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-command-line-tools-11-0.
# Preparing to unpack .../56-cuda-command-line-tools-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-command-line-tools-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-nsight-compute-11-0.
# Preparing to unpack .../57-cuda-nsight-compute-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-nsight-compute-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-nsight-systems-11-0.
# Preparing to unpack .../58-cuda-nsight-systems-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-nsight-systems-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-nsight-11-0.
# Preparing to unpack .../59-cuda-nsight-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nsight-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvml-dev-11-0.
# Preparing to unpack .../60-cuda-nvml-dev-11-0_11.0.167-1_amd64.deb ...
# Unpacking cuda-nvml-dev-11-0 (11.0.167-1) ...
# Selecting previously unselected package cuda-nvvp-11-0.
# Preparing to unpack .../61-cuda-nvvp-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvvp-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-visual-tools-11-0.
# Preparing to unpack .../62-cuda-visual-tools-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-visual-tools-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-tools-11-0.
# Preparing to unpack .../63-cuda-tools-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-tools-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-samples-11-0.
# Preparing to unpack .../64-cuda-samples-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-samples-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-documentation-11-0.
# Preparing to unpack .../65-cuda-documentation-11-0_11.0.207-1_amd64.deb ...
# Unpacking cuda-documentation-11-0 (11.0.207-1) ...
# Selecting previously unselected package cuda-toolkit-11-0.
# Preparing to unpack .../66-cuda-toolkit-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-toolkit-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-demo-suite-11-0.
# Preparing to unpack .../67-cuda-demo-suite-11-0_11.0.167-1_amd64.deb ...
# Unpacking cuda-demo-suite-11-0 (11.0.167-1) ...
# Selecting previously unselected package cuda-11-0.
# Preparing to unpack .../68-cuda-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../69-cuda_11.0.2-1_amd64.deb ...
# Unpacking cuda (11.0.2-1) ...
# Selecting previously unselected package libasan3:amd64.
# Preparing to unpack .../70-libasan3_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking libasan3:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package libgcc-6-dev:amd64.
# Preparing to unpack .../71-libgcc-6-dev_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking libgcc-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package gcc-6.
# Preparing to unpack .../72-gcc-6_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking gcc-6 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package libstdc++-6-dev:amd64.
# Preparing to unpack .../73-libstdc++-6-dev_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking libstdc++-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package g++-6.
# Preparing to unpack .../74-g++-6_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking g++-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up libnvidia-extra-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up libnvidia-compute-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up cuda-sanitizer-11-0 (11.0.194-1) ...
# Setting up cuda-nsight-systems-11-0 (11.0.2-1) ...
# Setting up gcc-6-base:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up cuda-memcheck-11-0 (11.0.194-1) ...
# Setting up cuda-nvprune-11-0 (11.0.167-1) ...
# Setting up libcufft-11-0 (10.2.0.218-1) ...
# Setting up libnvidia-fbc1-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up cuda-nsight-11-0 (11.0.194-1) ...
# Setting up libcusparse-11-0 (11.1.0.218-1) ...
# Setting up libcublas-11-0 (11.1.0.229-1) ...
# Setting up nvidia-utils-450 (450.51.05-0ubuntu1) ...
# Setting up cuda-nvdisasm-11-0 (11.0.194-1) ...
# Setting up nvidia-kernel-common-450 (450.51.05-0ubuntu1) ...
# Setting up libcusolver-11-0 (10.5.0.218-1) ...
# Setting up nvidia-settings (450.51.05-0ubuntu1) ...
# Setting up cuda-nvrtc-11-0 (11.0.194-1) ...
# Setting up cuda-nvprof-11-0 (11.0.194-1) ...
# Setting up libcusolver-dev-11-0 (10.5.0.218-1) ...
# Setting up cuda-nvtx-11-0 (11.0.167-1) ...
# Setting up libnpp-11-0 (11.1.0.218-1) ...
# Setting up nvidia-modprobe (450.51.05-0ubuntu1) ...
# Setting up nvidia-kernel-source-450 (450.51.05-0ubuntu1) ...
# Setting up libcurand-11-0 (10.2.1.218-1) ...
# Setting up libnvidia-cfg1-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up nvidia-dkms-450 (450.51.05-0ubuntu1) ...
#
# A modprobe blacklist file has been created at /etc/modprobe.d to prevent Nouveau
# from loading. This can be reverted by deleting the following file:
# /etc/modprobe.d/nvidia-graphics-drivers.conf
#
# A new initrd image has also been created. To revert, please regenerate your
# initrd by running the following command after deleting the modprobe.d file:
# `/usr/sbin/initramfs -u`
#
# *****************************************************************************
# *** Reboot your computer and verify that the NVIDIA graphics driver can   ***
# *** be loaded.                                                            ***
# *****************************************************************************
#
# Loading new nvidia-450.51.05 DKMS files...
# It is likely that 4.19.104+ belongs to a chroot's host
# Building for 4.15.0-108-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-108-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-108-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-108-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-108-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-108-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up libcublas-dev-11-0 (11.1.0.229-1) ...
# Setting up nvidia-compute-utils-450 (450.51.05-0ubuntu1) ...
# Setting up cuda-cuobjdump-11-0 (11.0.194-1) ...
# Setting up cpp-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up libcurand-dev-11-0 (10.2.1.218-1) ...
# Setting up libnpp-dev-11-0 (11.1.0.218-1) ...
# Setting up cuda-nvvp-11-0 (11.0.194-1) ...
# Setting up cuda-nvml-dev-11-0 (11.0.167-1) ...
# Setting up libnvjpeg-11-0 (11.1.0.218-1) ...
# Setting up libnvidia-common-450 (450.51.05-0ubuntu1) ...
# Setting up cuda-driver-dev-11-0 (11.0.194-1) ...
# Setting up cuda-cudart-11-0 (11.0.194-1) ...
# Setting up cuda-nsight-compute-11-0 (11.0.2-1) ...
# Setting up xserver-xorg-video-nvidia-450 (450.51.05-0ubuntu1) ...
# Setting up libcufft-dev-11-0 (10.2.0.218-1) ...
# Setting up libcusparse-dev-11-0 (11.1.0.218-1) ...
# Setting up libnvidia-decode-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up libasan3:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up cuda-gdb-11-0 (11.0.194-1) ...
# Setting up libgcc-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up libnvidia-encode-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up libnvjpeg-dev-11-0 (11.1.0.218-1) ...
# Setting up libstdc++-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up cuda-cudart-dev-11-0 (11.0.194-1) ...
# Setting up cuda-libraries-11-0 (11.0.2-1) ...
# Setting up cuda-nvrtc-dev-11-0 (11.0.194-1) ...
# Setting up gcc-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up g++-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up libnvidia-gl-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up cuda-visual-tools-11-0 (11.0.2-1) ...
# Setting up libnvidia-ifr1-450:amd64 (450.51.05-0ubuntu1) ...
# Setting up cuda-libraries-dev-11-0 (11.0.2-1) ...
# Setting up cuda-nvcc-11-0 (11.0.194-1) ...
# Setting up cuda-samples-11-0 (11.0.194-1) ...
# Setting up cuda-compiler-11-0 (11.0.2-1) ...
# Setting up nvidia-driver-450 (450.51.05-0ubuntu1) ...
# Setting up cuda-documentation-11-0 (11.0.207-1) ...
# Setting up cuda-cupti-11-0 (11.0.194-1) ...
# Setting up cuda-cupti-dev-11-0 (11.0.194-1) ...
# Setting up cuda-command-line-tools-11-0 (11.0.2-1) ...
# Setting up cuda-drivers-450 (450.51.05-1) ...
# Setting up cuda-tools-11-0 (11.0.2-1) ...
# Setting up cuda-drivers (450.51.05-1) ...
# Setting up cuda-toolkit-11-0 (11.0.2-1) ...
# Setting up cuda-runtime-11-0 (11.0.2-1) ...
# Setting up cuda-demo-suite-11-0 (11.0.167-1) ...
# Setting up cuda-11-0 (11.0.2-1) ...
# Setting up cuda (11.0.2-1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
#    Cloning default registries into /root/.julia/registries
#    Cloning registry General from "https://github.com/JuliaRegistries/General.git"
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#  Installed SoftGlobalScope ─ v1.0.10
#  Installed VersionParsing ── v1.2.0
#  Installed Conda ─────────── v1.4.1
#  Installed ZMQ ───────────── v1.1.0
#  Installed Parsers ───────── v1.0.7
#  Installed BinaryProvider ── v0.5.10
#  Installed IJulia ────────── v1.21.2
#  Installed MbedTLS ───────── v0.6.8
#  Installed JSON ──────────── v0.21.0
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [7073ff75] + IJulia v1.21.2
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [b99e7846] + BinaryProvider v0.5.10
#   [8f4d0f93] + Conda v1.4.1
#   [7073ff75] + IJulia v1.21.2
#   [682c06a0] + JSON v0.21.0
#   [739be429] + MbedTLS v0.6.8
#   [69de0a69] + Parsers v1.0.7
#   [b85f4697] + SoftGlobalScope v1.0.10
#   [81def892] + VersionParsing v1.2.0
#   [c2297ded] + ZMQ v1.1.0
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8ba89e20] + Distributed
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   Building Conda ──→ `~/.julia/packages/Conda/3rPhK/deps/build.log`
#   Building ZMQ ────→ `~/.julia/packages/ZMQ/ItfqT/deps/build.log`
#   Building MbedTLS → `~/.julia/packages/MbedTLS/X4xar/deps/build.log`
#   Building IJulia ─→ `~/.julia/packages/IJulia/DrVMH/deps/build.log`
#  Resolving package versions...
#  Installed Adapt ────────────── v1.1.0
#  Installed CEnum ────────────── v0.2.0
#  Installed GPUArrays ────────── v2.0.1
#  Installed MacroTools ───────── v0.5.5
#  Installed NNlib ────────────── v0.6.6
#  Installed DataStructures ───── v0.17.19
#  Installed LLVM ─────────────── v1.7.0
#  Installed CuArrays ─────────── v1.6.0
#  Installed TimerOutputs ─────── v0.5.6
#  Installed Requires ─────────── v1.0.1
#  Installed CUDAapi ──────────── v2.1.0
#  Installed AbstractFFTs ─────── v0.5.0
#  Installed OrderedCollections ─ v1.3.0
#  Installed CUDAdrv ──────────── v5.1.0
#  Installed CUDAnative ───────── v2.7.0
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [3a865a2d] + CuArrays v1.6.0
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.5.0
#   [79e6a3ab] + Adapt v1.1.0
#   [fa961155] + CEnum v0.2.0
#   [3895d2a7] + CUDAapi v2.1.0
#   [c5f51814] + CUDAdrv v5.1.0
#   [be33ccc6] + CUDAnative v2.7.0
#   [3a865a2d] + CuArrays v1.6.0
#   [864edb3b] + DataStructures v0.17.19
#   [0c68f7d7] + GPUArrays v2.0.1
#   [929cbde3] + LLVM v1.7.0
#   [1914dd2f] + MacroTools v0.5.5
#   [872c559c] + NNlib v0.6.6
#   [bac558e1] + OrderedCollections v1.3.0
#   [ae029012] + Requires v1.0.1
#   [a759f4b9] + TimerOutputs v0.5.6
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   Building NNlib → `~/.julia/packages/NNlib/FAI3o/deps/build.log`
#  Resolving package versions...
#  Installed Media ──────────────── v0.5.0
#  Installed DiffRules ──────────── v1.0.1
#  Installed CodecZlib ──────────── v0.6.0
#  Installed FixedPointNumbers ──── v0.7.1
#  Installed ZipFile ────────────── v0.8.4
#  Installed FillArrays ─────────── v0.8.12
#  Installed Flux ───────────────── v0.10.3
#  Installed Colors ─────────────── v0.11.2
#  Installed NaNMath ────────────── v0.3.3
#  Installed Missings ───────────── v0.4.3
#  Installed URIParser ──────────── v0.4.1
#  Installed ZygoteRules ────────── v0.2.0
#  Installed ForwardDiff ────────── v0.10.12
#  Installed CommonSubexpressions ─ v0.3.0
#  Installed Zygote ─────────────── v0.4.8
#  Installed SortingAlgorithms ──── v0.3.1
#  Installed FFTW ───────────────── v1.1.0
#  Installed Reexport ───────────── v0.2.0
#  Installed DiffResults ────────── v1.0.2
#  Installed Juno ───────────────── v0.8.2
#  Installed DataAPI ────────────── v1.3.0
#  Installed ColorTypes ─────────── v0.9.1
#  Installed SpecialFunctions ───── v0.8.0
#  Installed BinDeps ────────────── v1.0.1
#  Installed AbstractTrees ──────── v0.3.3
#  Installed IRTools ────────────── v0.3.3
#  Installed TranscodingStreams ─── v0.9.5
#  Installed StatsBase ──────────── v0.33.0
#  Installed StaticArrays ───────── v0.12.4
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [587475ba] + Flux v0.10.3
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [1520ce14] + AbstractTrees v0.3.3
#   [9e28174c] + BinDeps v1.0.1
#   [944b1d66] + CodecZlib v0.6.0
#   [3da002f7] + ColorTypes v0.9.1
#   [5ae59095] + Colors v0.11.2
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [9a962f9c] + DataAPI v1.3.0
#   [163ba53b] + DiffResults v1.0.2
#   [b552c78f] + DiffRules v1.0.1
#   [7a1cc6ca] + FFTW v1.1.0
#   [1a297f60] + FillArrays v0.8.12
#   [53c48c17] + FixedPointNumbers v0.7.1
#   [587475ba] + Flux v0.10.3
#   [f6369f11] + ForwardDiff v0.10.12
#   [7869d1d1] + IRTools v0.3.3
#   [e5e0dc1b] + Juno v0.8.2
#   [e89f7d12] + Media v0.5.0
#   [e1d29d7a] + Missings v0.4.3
#   [77ba4419] + NaNMath v0.3.3
#   [189a3867] + Reexport v0.2.0
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [276daf66] + SpecialFunctions v0.8.0
#   [90137ffa] + StaticArrays v0.12.4
#   [2913bbd2] + StatsBase v0.33.0
#   [3bb67fe8] + TranscodingStreams v0.9.5
#   [30578b45] + URIParser v0.4.1
#   [a5390f91] + ZipFile v0.8.4
#   [e88e6eb3] + Zygote v0.4.8
#   [700de1a5] + ZygoteRules v0.2.0
#   [8bb1440f] + DelimitedFiles
#   [9abbd945] + Profile
#   Building ZipFile ─────────→ `~/.julia/packages/ZipFile/DW0Qr/deps/build.log`
#   Building CodecZlib ───────→ `~/.julia/packages/CodecZlib/5t9zO/deps/build.log`
#   Building FFTW ────────────→ `~/.julia/packages/FFTW/loJ3F/deps/build.log`
#   Building SpecialFunctions → `~/.julia/packages/SpecialFunctions/ne2iw/deps/build.log`
# Precompiling project...
# Precompiling CuArrays
# ERROR: LoadError: LoadError: LoadError: syntax: "CuArrays.CURAND.err" is not a valid function argument name
# Stacktrace:
#  [1] include at ./boot.jl:317 [inlined]
#  [2] include_relative(::Module, ::String) at ./loading.jl:1038
#  [3] include at ./sysimg.jl:29 [inlined]
#  [4] include(::String) at /root/.julia/packages/CuArrays/rNxse/src/rand/CURAND.jl:1
#  [5] top-level scope at none:0
#  [6] include at ./boot.jl:317 [inlined]
#  [7] include_relative(::Module, ::String) at ./loading.jl:1038
#  [8] include at ./sysimg.jl:29 [inlined]
#  [9] include(::String) at /root/.julia/packages/CuArrays/rNxse/src/CuArrays.jl:1
#  [10] top-level scope at none:0
#  [11] include at ./boot.jl:317 [inlined]
#  [12] include_relative(::Module, ::String) at ./loading.jl:1038
#  [13] include(::Module, ::String) at ./sysimg.jl:29
#  [14] top-level scope at none:2
#  [15] eval at ./boot.jl:319 [inlined]
#  [16] eval(::Expr) at ./client.jl:389
#  [17] top-level scope at ./none:3
# in expression starting at /root/.julia/packages/CuArrays/rNxse/src/rand/random.jl:16
# in expression starting at /root/.julia/packages/CuArrays/rNxse/src/rand/CURAND.jl:25
# in expression starting at /root/.julia/packages/CuArrays/rNxse/src/CuArrays.jl:39
# ERROR: Failed to precompile CuArrays [3a865a2d-5b23-5a0f-bc46-62713ec82fae] to /root/.julia/compiled/v1.0/CuArrays/7YFE0.ji.
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] macro expansion at ./logging.jl:313 [inlined]
#  [3] compilecache(::Base.PkgId, ::String) at ./loading.jl:1184
#  [4] precompile(::Pkg.Types.Context) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.0/Pkg/src/API.jl:489
#  [5] do_precompile!(::Dict{Symbol,Any}, ::Array{String,1}, ::Dict{Symbol,Any}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.0/Pkg/src/REPLMode.jl:586
#  [6] #invokelatest#1(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::Any, ::Any, ::Vararg{Any,N} where N) at ./essentials.jl:686
#  [7] invokelatest(::Any, ::Any, ::Vararg{Any,N} where N) at ./essentials.jl:685
#  [8] do_cmd!(::Pkg.REPLMode.PkgCommand, ::Pkg.REPLMode.MiniREPL) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.0/Pkg/src/REPLMode.jl:542
#  [9] #do_cmd#30(::Bool, ::Function, ::Pkg.REPLMode.MiniREPL, ::String) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.0/Pkg/src/REPLMode.jl:507
#  [10] (::getfield(Pkg.REPLMode, Symbol("#kw##do_cmd")))(::NamedTuple{(:do_rethrow,),Tuple{Bool}}, ::typeof(Pkg.REPLMode.do_cmd), ::Pkg.REPLMode.MiniREPL, ::String) at ./none:0
#  [11] top-level scope at none:0

# %%
# !jupyter kernelspec list
